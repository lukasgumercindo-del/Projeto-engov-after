# %%
import pandas as pd
import numpy as np

np.random.seed(42)

datas = pd.date_range(start="2020-01-01", end="2026-06-30", freq="D")

produtos_info = {
    "Citrus": {"ano_lancamento": 2020, "preco_base": 7.50},
    "Tangerina": {"ano_lancamento": 2020, "preco_base": 7.50},
    "Berry Vital": {"ano_lancamento": 2022, "preco_base": 8.00},
    "Red Energy": {"ano_lancamento": 2022, "preco_base": 8.00},
    "Mental Drink Brabo": {"ano_lancamento": 2024, "preco_base": 8.90}
}

registros = []

for data in datas:
    ano = data.year
    mes = data.month
    
    fator_sazonal = 1.0
    if mes == 2:
        fator_sazonal = 2.5
    elif mes == 12:
        fator_sazonal = 1.8
    elif mes in [1, 3, 7]:
        fator_sazonal = 1.3

    for produto, info in produtos_info.items():
        if ano >= info["ano_lancamento"]:
            crescimento_ano = 1 + (ano - 2020) * 0.15
            volume_base = np.random.randint(500, 1500)
            
            quantidade_vendida = int(volume_base * fator_sazonal * crescimento_ano)
            
            preco_unitario = round(info["preco_base"] * np.random.uniform(0.95, 1.08), 2)
            faturamento_total = round(quantidade_vendida * preco_unitario, 2)
            
            registros.append({
                "data": data,
                "produto": f"Engov After {produto}",
                "sabor": produto,
                "quantidade_vendida": quantidade_vendida,
                "preco_unitario": preco_unitario,
                "faturamento_total": faturamento_total
            })

df_vendas = pd.DataFrame(registros)
df_vendas.to_csv("vendas_engov_after_2020_2026.csv", index=False)

print(f"Base de dados gerada com sucesso! Total de linhas: {df_vendas.shape[0]}")
# Out:
# Base de dados gerada com sucesso! Total de linhas: 8942

# %%
import pandas as pd 

df = pd.read_csv("vendas_engov_after_2020_2026.csv")
df.head().style.set_table_styles(
    [{'selector': 'th', 'props': [('background-color', "#ddd3d3"), ('color', '#333'), ('font-weight', 'bold')]},]
).format({'preco_unitario': 'R${:.2f}', 'faturamento_total': 'R${:.2f}'})
# Out:
# <style type="text/css">
# #T_f915c th {
#   background-color: #ddd3d3;
#   color: #333;
#   font-weight: bold;
# }
# </style>
# <table id="T_f915c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f915c_level0_col0" class="col_heading level0 col0" >data</th>
#       <th id="T_f915c_level0_col1" class="col_heading level0 col1" >produto</th>
#       <th id="T_f915c_level0_col2" class="col_heading level0 col2" >sabor</th>
#       <th id="T_f915c_level0_col3" class="col_heading level0 col3" >quantidade_vendida</th>
#       <th id="T_f915c_level0_col4" class="col_heading level0 col4" >preco_unitario</th>
#       <th id="T_f915c_level0_col5" class="col_heading level0 col5" >faturamento_total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f915c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f915c_row0_col0" class="data row0 col0" >2020-01-01</td>
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8942 entries, 0 to 8941
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   data                8942 non-null   object
#  1   produto             8942 non-null   object
#  2   sabor               8942 non-null   object
#  3   quantidade_vendida  8942 non-null   int64
#  4   preco_unitario      8942 non-null   float64
#  5   faturamento_total   8942 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 419.3+ KB

# %%
# !pip install plotly

# %%
import plotly.express as px 

faturamento_por_sabor = df.groupby('sabor')['faturamento_total'].sum().sort_values(ascending=False).reset_index()

fig_faturamento_por_sabor = px.bar(
    faturamento_por_sabor,
    x = 'sabor',
    y = 'faturamento_total', 
    title = 'Faturamento Total por Sabor (Engov After 2020-2026)',
    labels = {'sabor': 'Sabor', 'faturamento_total': 'Faturamento Total (R$)'},
    color = 'faturamento_total',
    color_continuous_scale = 'Blues'
)

fig_faturamento_por_sabor.update_layout(
    yaxis_tickprefix='R$',
    yaxis_tickformat=',.2f',
    title_x=0.5
)
fig_faturamento_por_sabor.show()

# %%
valor_por_sabor = df.groupby('sabor')['quantidade_vendida'].sum().sort_values(ascending=False).reset_index()

fig_volume = px.bar(
    valor_por_sabor,
    x='sabor',
    y='quantidade_vendida',
    title='Volume Total de Unidades Vendidas por Sabor (2020-2026)',
    labels={'sabor': 'Sabor do Produto', 'quantidade_vendida': 'Total de Unidades Vendidas'},
    color='quantidade_vendida',
    color_continuous_scale='Greens'
)
fig_volume.show()

fig_faturamento_por_sabor.update_layout(
    yaxis_tickprefix='R$',
    yaxis_tickformat=',.2f',
    title_x=0.5
)
fig_faturamento_por_sabor.show()

# %%
df['data'] = pd.to_datetime(df['data'])
df['ano'] = df['data'].dt.year

faturamento_por_ano = df.groupby('ano')['faturamento_total'].sum().reset_index()

fig_temporal = px.line(
    faturamento_por_ano, 
    x = 'ano',
    y = 'faturamento_total',
    title = 'Evolução do Faturamento Anual de Vendas (2020-2026)',
    labels = {'ano': 'Ano Comcercial', 'faturamento_total': 'Faturamento Total (R$)'},
    markers = True
) 
fig_temporal.update_traces(line_color=' #FF5733', line_width=3)
fig_temporal.update_layout( yaxis_tickprefix='R$',
    yaxis_tickformat=',.2f',
    title_x=0.5)
fig_temporal.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df ['ano'] = df ['data'].dt.year
#       3 faturamento_por_ano = df.groupby('ano')['faturamento_total'].sum().reset_index()
#       5 fig_temporal = px.line(
#       6     faturamento_por_ano,
#       7     x = 'ano',
#    (...)     11     markers = True
#      12 )
#
# File c:\Users\lukin\anaconda2\Lib\site-packages\pandas\core\generic.py:6321, in NDFrame.__getattr__(self, name)
#    6314 if (
#    6315     name not in self._internal_names_set
#    6316     and name not in self._metadata
#    6317     and name not in self._accessors
#    6318     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319 ):
#    6320     return self[name]
# -> 6321 return object.__getattribute__(self, name)
#
# ...
